# %%
Percent=100

# %% [markdown]
# # Data Visualization

# %% [markdown]
# #### Importing Modules

# %%
#import modules
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
import splitfolders
from Helper import Visualize,Data,Model
import random as rd

# %% [markdown]
# #### Time Stamp

# %%
#Print Time stamp
print(f"Notebook last run (end-to-end): {datetime.datetime.now()}")
print(f"Tensorflow_version: {tf.__version__}")
# Out:
# Notebook last run (end-to-end): 2023-10-22 22:35:22.492835
# Tensorflow_version: 2.12.0

# %% [markdown]
# #### Initalizing Path

# %%
Expt_Name="Image_"+str(Percent)
#Initalize path
raw_data_path="Data\Raw_image\\"
data_path="Data\\"+Expt_Name+"%\\"
train_path=data_path+"train\\"
val_path=data_path+"val\\"
test_path=data_path+"test\\"
label_path="JSON\\"+Expt_Name+".json"

# %% [markdown]
# #### Split Data into Train/Valadation/Testing

# %%
splitfolders.ratio(raw_data_path, output=data_path,seed=42, ratio=(0.7,0.1,0.2), group_prefix=None, move=False)
# Out:
# Copying files: 101000 files [27:41, 60.77 files/s]

# %% [markdown]
# #### Structure of text

# %%
#Data
Visualize.walk_through_dir(data_path)
# Out:
# There are 3 directories and 0 images in 'Data\Image_100%\'.
# There are 101 directories and 0 images in 'Data\Image_100%\test'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\apple_pie'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\baby_back_ribs'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\baklava'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\beef_carpaccio'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\beef_tartare'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\beet_salad'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\beignets'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\bibimbap'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\bread_pudding'.
# There are 0 directories and 200 images in 'Data\Image_100%\test\breakfast_burrito'.
# ...

# %%
#Train 
Visualize.walk_through_dir(train_path)
# Out:
# There are 101 directories and 0 images in 'Data\Image_100%\train\'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\apple_pie'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\baby_back_ribs'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\baklava'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\beef_carpaccio'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\beef_tartare'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\beet_salad'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\beignets'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\bibimbap'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\bread_pudding'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\breakfast_burrito'.
# There are 0 directories and 700 images in 'Data\Image_100%\train\bruschetta'.
# ...

# %%
#Val
Visualize.walk_through_dir(val_path)

# %%
#Test
Visualize.walk_through_dir(test_path)

# %% [markdown]
# #### Create Json file with Labels

# %%
Data.put_labels(data_path=train_path,label_path=label_path)

# %%
labels,no_of_classes=Data.get_labels(label_path=label_path).values()

# %%
print(labels)
print(no_of_classes)
# Out:
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheesecake', 'cheese_plate', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_s
# ...

# %% [markdown]
# #### Visualize data

# %%
#Visualize image
label=labels[rd.randint(0,no_of_classes-1)]
img_name=os.listdir(raw_data_path+label+"/")[rd.randint(0,len(os.listdir(raw_data_path+label))-1)]
img_file=raw_data_path+label+"/"+img_name
plt.imshow(plt.imread(img_file))
plt.title(label)
plt.axis('off');
