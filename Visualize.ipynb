# %% [markdown]
# # Data Visualization

# %% [markdown]
# #### Importing Modules

# %%
#import modules
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
import splitfolders
from Helper import Visualize,Data,Model

# %% [markdown]
# #### Time Stamp

# %%
#Print Time stamp
print(f"Notebook last run (end-to-end): {datetime.datetime.now()}")
print(f"Tensorflow_version: {tf.__version__}")
# Out:
# Notebook last run (end-to-end): 2023-10-22 22:35:22.492835
# Tensorflow_version: 2.12.0

# %% [markdown]
# #### Initalizing Path

# %%
#Initalize path
raw_data_path="Data\Raw_image\\"
data_path="Data\Image_100%\\"
train_path=data_path+"train\\"
val_path=data_path+"val\\"
test_path=data_path+"test\\"

# %% [markdown]
# #### Split Data into Train/Valadation/Testing

# %%
splitfolders.ratio(raw_data_path, output=data_path,seed=42, ratio=(0.7,0.1,0.2), group_prefix=None, move=False)
# Out:
# Copying files: 101000 files [27:41, 60.77 files/s]

# %% [markdown]
# #### Structure of text

# %%
Visualize.walk_through_dir(data_path)
# Out:
# Data\Image_100% In there are  3  files and  0 images
# Data\Image_100%\test In there are  101  files and  0 images
# Data\Image_100%\test\apple_pie In there are  0  files and  200 images
# Data\Image_100%\test\baby_back_ribs In there are  0  files and  200 images
# Data\Image_100%\test\baklava In there are  0  files and  200 images
# Data\Image_100%\test\beef_carpaccio In there are  0  files and  200 images
# Data\Image_100%\test\beef_tartare In there are  0  files and  200 images
# Data\Image_100%\test\beet_salad In there are  0  files and  200 images
# Data\Image_100%\test\beignets In there are  0  files and  200 images
# Data\Image_100%\test\bibimbap In there are  0  files and  200 images
# Data\Image_100%\test\bread_pudding In there are  0  files and  200 images
# Data\Image_100%\test\breakfast_burrito In there are  0  files and  200 images
# Data\Image_100%\test\bruschetta In there are  0  files and  200 images
# Data\Image_100%\test\caesar_salad In there are  0  files and  200 images
# Data\Image_100%\test\cannoli In there are  0  files and  200 images
# Data\Image_100%\test\caprese_salad In there are  0  files and  200 images
# Data\Image_100%\test\carrot_cake In there are  0  files and  200 images
# Data\Image_100%\test\ceviche In there are  0  files and  200 images
# Data\Image_100%\test\cheesecake In there are  0  files and  200 images
# Data\Image_100%\test\cheese_plate In there are  0  files and  200 images
# Data\Image_100%\test\chicken_curry In there are  0  files and  200 images
# Data\Image_100%\test\chicken_quesadilla In there are  0  files and  200 images
# Data\Image_100%\test\chicken_wings In there are  0  files and  200 images
# Data\Image_100%\test\chocolate_cake In there are  0  files and  200 images
# Data\Image_100%\test\chocolate_mousse In there are  0  files and  200 images
# Data\Image_100%\test\churros In there are  0  files and  200 images
# Data\Image_100%\test\clam_chowder In there are  0  files and  200 images
# Data\Image_100%\test\club_sandwich In there are  0  files and  200 images
# Data\Image_100%\test\crab_cakes In there are  0  files and  200 images
# Data\Image_100%\test\creme_brulee In there are  0  files and  200 images
# Data\Image_100%\test\croque_madame In there are  0  files and  200 images
# Data\Image_100%\test\cup_cakes In there are  0  files and  200 images
# Data\Image_100%\test\deviled_eggs In there are  0  files and  200 images
# Data\Image_100%\test\donuts In there are  0  files and  200 images
# Data\Image_100%\test\dumplings In there are  0  files and  200 images
# Data\Image_100%\test\edamame In there are  0  files and  200 images
# Data\Image_100%\test\eggs_benedict In there are  0  files and  200 images
# Data\Image_100%\test\escargots In there are  0  files and  200 images
# Data\Image_100%\test\falafel In there are  0  files and  200 images
# Data\Image_100%\test\filet_mignon In there are  0  files and  200 images
# Data\Image_100%\test\fish_and_chips In there are  0  files and  200 images
# Data\Image_100%\test\foie_gras In there are  0  files and  200 images
# Data\Image_100%\test\french_fries In there are  0  files and  200 images
# Data\Image_100%\test\french_onion_soup In there are  0  files and  200 images
# Data\Image_100%\test\french_toast In there are  0  files and  200 images
# Data\Image_100%\test\fried_calamari In there are  0  files and  200 images
# Data\Image_100%\test\fried_rice In there are  0  files and  200 images
# Data\Image_100%\test\frozen_yogurt In there are  0  files and  200 images
# Data\Image_100%\test\garlic_bread In there are  0  files and  200 images
# Data\Image_100%\test\gnocchi In there are  0  files and  200 images
# Data\Image_100%\test\greek_salad In there are  0  files and  200 images
# Data\Image_100%\test\grilled_cheese_sandwich In there are  0  files and  200 images
# Data\Image_100%\test\grilled_salmon In there are  0  files and  200 images
# Data\Image_100%\test\guacamole In there are  0  files and  200 images
# Data\Image_100%\test\gyoza In there are  0  files and  200 images
# Data\Image_100%\test\hamburger In there are  0  files and  200 images
# Data\Image_100%\test\hot_and_sour_soup In there are  0  files and  200 images
# Data\Image_100%\test\hot_dog In there are  0  files and  200 images
# Data\Image_100%\test\huevos_rancheros In there are  0  files and  200 images
# Data\Image_100%\test\hummus In there are  0  files and  200 images
# Data\Image_100%\test\ice_cream In there are  0  files and  200 images
# Data\Image_100%\test\lasagna In there are  0  files and  200 images
# Data\Image_100%\test\lobster_bisque In there are  0  files and  200 images
# Data\Image_100%\test\lobster_roll_sandwich In there are  0  files and  200 images
# Data\Image_100%\test\macaroni_and_cheese In there are  0  files and  200 images
# Data\Image_100%\test\macarons In there are  0  files and  200 images
# Data\Image_100%\test\miso_soup In there are  0  files and  200 images
# Data\Image_100%\test\mussels In there are  0  files and  200 images
# Data\Image_100%\test\nachos In there are  0  files and  200 images
# Data\Image_100%\test\omelette In there are  0  files and  200 images
# Data\Image_100%\test\onion_rings In there are  0  files and  200 images
# Data\Image_100%\test\oysters In there are  0  files and  200 images
# Data\Image_100%\test\pad_thai In there are  0  files and  200 images
# Data\Image_100%\test\paella In there are  0  files and  200 images
# Data\Image_100%\test\pancakes In there are  0  files and  200 images
# Data\Image_100%\test\panna_cotta In there are  0  files and  200 images
# Data\Image_100%\test\peking_duck In there are  0  files and  200 images
# Data\Image_100%\test\pho In there are  0  files and  200 images
# Data\Image_100%\test\pizza In there are  0  files and  200 images
# Data\Image_100%\test\pork_chop In there are  0  files and  200 images
# Data\Image_100%\test\poutine In there are  0  files and  200 images
# Data\Image_100%\test\prime_rib In there are  0  files and  200 images
# Data\Image_100%\test\pulled_pork_sandwich In there are  0  files and  200 images
# Data\Image_100%\test\ramen In there are  0  files and  200 images
# Data\Image_100%\test\ravioli In there are  0  files and  200 images
# Data\Image_100%\test\red_velvet_cake In there are  0  files and  200 images
# Data\Image_100%\test\risotto In there are  0  files and  200 images
# Data\Image_100%\test\samosa In there are  0  files and  200 images
# Data\Image_100%\test\sashimi In there are  0  files and  200 images
# Data\Image_100%\test\scallops In there are  0  files and  200 images
# Data\Image_100%\test\seaweed_salad In there are  0  files and  200 images
# Data\Image_100%\test\shrimp_and_grits In there are  0  files and  200 images
# Data\Image_100%\test\spaghetti_bolognese In there are  0  files and  200 images
# Data\Image_100%\test\spaghetti_carbonara In there are  0  files and  200 images
# Data\Image_100%\test\spring_rolls In there are  0  files and  200 images
# Data\Image_100%\test\steak In there are  0  files and  200 images
# Data\Image_100%\test\strawberry_shortcake In there are  0  files and  200 images
# Data\Image_100%\test\sushi In there are  0  files and  200 images
# Data\Image_100%\test\tacos In there are  0  files and  200 images
# Data\Image_100%\test\takoyaki In there are  0  files and  200 images
# Data\Image_100%\test\tiramisu In there are  0  files and  200 images
# Data\Image_100%\test\tuna_tartare In there are  0  files and  200 images
# Data\Image_100%\test\waffles In there are  0  files and  200 images
# Data\Image_100%\train In there are  101  files and  0 images
# Data\Image_100%\train\apple_pie In there are  0  files and  700 images
# Data\Image_100%\train\baby_back_ribs In there are  0  files and  700 images
# Data\Image_100%\train\baklava In there are  0  files and  700 images
# Data\Image_100%\train\beef_carpaccio In there are  0  files and  700 images
# Data\Image_100%\train\beef_tartare In there are  0  files and  700 images
# Data\Image_100%\train\beet_salad In there are  0  files and  700 images
# Data\Image_100%\train\beignets In there are  0  files and  700 images
# Data\Image_100%\train\bibimbap In there are  0  files and  700 images
# Data\Image_100%\train\bread_pudding In there are  0  files and  700 images
# Data\Image_100%\train\breakfast_burrito In there are  0  files and  700 images
# Data\Image_100%\train\bruschetta In there are  0  files and  700 images
# Data\Image_100%\train\caesar_salad In there are  0  files and  700 images
# Data\Image_100%\train\cannoli In there are  0  files and  700 images
# Data\Image_100%\train\caprese_salad In there are  0  files and  700 images
# Data\Image_100%\train\carrot_cake In there are  0  files and  700 images
# Data\Image_100%\train\ceviche In there are  0  files and  700 images
# Data\Image_100%\train\cheesecake In there are  0  files and  700 images
# Data\Image_100%\train\cheese_plate In there are  0  files and  700 images
# Data\Image_100%\train\chicken_curry In there are  0  files and  700 images
# Data\Image_100%\train\chicken_quesadilla In there are  0  files and  700 images
# Data\Image_100%\train\chicken_wings In there are  0  files and  700 images
# Data\Image_100%\train\chocolate_cake In there are  0  files and  700 images
# Data\Image_100%\train\chocolate_mousse In there are  0  files and  700 images
# Data\Image_100%\train\churros In there are  0  files and  700 images
# Data\Image_100%\train\clam_chowder In there are  0  files and  700 images
# Data\Image_100%\train\club_sandwich In there are  0  files and  700 images
# Data\Image_100%\train\crab_cakes In there are  0  files and  700 images
# Data\Image_100%\train\creme_brulee In there are  0  files and  700 images
# Data\Image_100%\train\croque_madame In there are  0  files and  700 images
# Data\Image_100%\train\cup_cakes In there are  0  files and  700 images
# Data\Image_100%\train\deviled_eggs In there are  0  files and  700 images
# Data\Image_100%\train\donuts In there are  0  files and  700 images
# Data\Image_100%\train\dumplings In there are  0  files and  700 images
# Data\Image_100%\train\edamame In there are  0  files and  700 images
# Data\Image_100%\train\eggs_benedict In there are  0  files and  700 images
# Data\Image_100%\train\escargots In there are  0  files and  700 images
# Data\Image_100%\train\falafel In there are  0  files and  700 images
# Data\Image_100%\train\filet_mignon In there are  0  files and  700 images
# Data\Image_100%\train\fish_and_chips In there are  0  files and  700 images
# Data\Image_100%\train\foie_gras In there are  0  files and  700 images
# Data\Image_100%\train\french_fries In there are  0  files and  700 images
# Data\Image_100%\train\french_onion_soup In there are  0  files and  700 images
# Data\Image_100%\train\french_toast In there are  0  files and  700 images
# Data\Image_100%\train\fried_calamari In there are  0  files and  700 images
# Data\Image_100%\train\fried_rice In there are  0  files and  700 images
# Data\Image_100%\train\frozen_yogurt In there are  0  files and  700 images
# Data\Image_100%\train\garlic_bread In there are  0  files and  700 images
# Data\Image_100%\train\gnocchi In there are  0  files and  700 images
# Data\Image_100%\train\greek_salad In there are  0  files and  700 images
# Data\Image_100%\train\grilled_cheese_sandwich In there are  0  files and  700 images
# Data\Image_100%\train\grilled_salmon In there are  0  files and  700 images
# Data\Image_100%\train\guacamole In there are  0  files and  700 images
# Data\Image_100%\train\gyoza In there are  0  files and  700 images
# Data\Image_100%\train\hamburger In there are  0  files and  700 images
# Data\Image_100%\train\hot_and_sour_soup In there are  0  files and  700 images
# Data\Image_100%\train\hot_dog In there are  0  files and  700 images
# Data\Image_100%\train\huevos_rancheros In there are  0  files and  700 images
# Data\Image_100%\train\hummus In there are  0  files and  700 images
# Data\Image_100%\train\ice_cream In there are  0  files and  700 images
# Data\Image_100%\train\lasagna In there are  0  files and  700 images
# Data\Image_100%\train\lobster_bisque In there are  0  files and  700 images
# Data\Image_100%\train\lobster_roll_sandwich In there are  0  files and  700 images
# Data\Image_100%\train\macaroni_and_cheese In there are  0  files and  700 images
# Data\Image_100%\train\macarons In there are  0  files and  700 images
# Data\Image_100%\train\miso_soup In there are  0  files and  700 images
# Data\Image_100%\train\mussels In there are  0  files and  700 images
# Data\Image_100%\train\nachos In there are  0  files and  700 images
# Data\Image_100%\train\omelette In there are  0  files and  700 images
# Data\Image_100%\train\onion_rings In there are  0  files and  700 images
# Data\Image_100%\train\oysters In there are  0  files and  700 images
# Data\Image_100%\train\pad_thai In there are  0  files and  700 images
# Data\Image_100%\train\paella In there are  0  files and  700 images
# Data\Image_100%\train\pancakes In there are  0  files and  700 images
# Data\Image_100%\train\panna_cotta In there are  0  files and  700 images
# Data\Image_100%\train\peking_duck In there are  0  files and  700 images
# Data\Image_100%\train\pho In there are  0  files and  700 images
# Data\Image_100%\train\pizza In there are  0  files and  700 images
# Data\Image_100%\train\pork_chop In there are  0  files and  700 images
# Data\Image_100%\train\poutine In there are  0  files and  700 images
# Data\Image_100%\train\prime_rib In there are  0  files and  700 images
# Data\Image_100%\train\pulled_pork_sandwich In there are  0  files and  700 images
# Data\Image_100%\train\ramen In there are  0  files and  700 images
# Data\Image_100%\train\ravioli In there are  0  files and  700 images
# Data\Image_100%\train\red_velvet_cake In there are  0  files and  700 images
# Data\Image_100%\train\risotto In there are  0  files and  700 images
# Data\Image_100%\train\samosa In there are  0  files and  700 images
# Data\Image_100%\train\sashimi In there are  0  files and  700 images
# Data\Image_100%\train\scallops In there are  0  files and  700 images
# Data\Image_100%\train\seaweed_salad In there are  0  files and  700 images
# Data\Image_100%\train\shrimp_and_grits In there are  0  files and  700 images
# Data\Image_100%\train\spaghetti_bolognese In there are  0  files and  700 images
# Data\Image_100%\train\spaghetti_carbonara In there are  0  files and  700 images
# Data\Image_100%\train\spring_rolls In there are  0  files and  700 images
# Data\Image_100%\train\steak In there are  0  files and  700 images
# Data\Image_100%\train\strawberry_shortcake In there are  0  files and  700 images
# Data\Image_100%\train\sushi In there are  0  files and  700 images
# Data\Image_100%\train\tacos In there are  0  files and  700 images
# Data\Image_100%\train\takoyaki In there are  0  files and  700 images
# Data\Image_100%\train\tiramisu In there are  0  files and  700 images
# Data\Image_100%\train\tuna_tartare In there are  0  files and  700 images
# Data\Image_100%\train\waffles In there are  0  files and  700 images
# Data\Image_100%\val In there are  101  files and  0 images
# Data\Image_100%\val\apple_pie In there are  0  files and  100 images
# Data\Image_100%\val\baby_back_ribs In there are  0  files and  100 images
# Data\Image_100%\val\baklava In there are  0  files and  100 images
# Data\Image_100%\val\beef_carpaccio In there are  0  files and  100 images
# Data\Image_100%\val\beef_tartare In there are  0  files and  100 images
# Data\Image_100%\val\beet_salad In there are  0  files and  100 images
# Data\Image_100%\val\beignets In there are  0  files and  100 images
# Data\Image_100%\val\bibimbap In there are  0  files and  100 images
# Data\Image_100%\val\bread_pudding In there are  0  files and  100 images
# Data\Image_100%\val\breakfast_burrito In there are  0  files and  100 images
# Data\Image_100%\val\bruschetta In there are  0  files and  100 images
# Data\Image_100%\val\caesar_salad In there are  0  files and  100 images
# Data\Image_100%\val\cannoli In there are  0  files and  100 images
# Data\Image_100%\val\caprese_salad In there are  0  files and  100 images
# Data\Image_100%\val\carrot_cake In there are  0  files and  100 images
# Data\Image_100%\val\ceviche In there are  0  files and  100 images
# Data\Image_100%\val\cheesecake In there are  0  files and  100 images
# Data\Image_100%\val\cheese_plate In there are  0  files and  100 images
# Data\Image_100%\val\chicken_curry In there are  0  files and  100 images
# Data\Image_100%\val\chicken_quesadilla In there are  0  files and  100 images
# Data\Image_100%\val\chicken_wings In there are  0  files and  100 images
# Data\Image_100%\val\chocolate_cake In there are  0  files and  100 images
# Data\Image_100%\val\chocolate_mousse In there are  0  files and  100 images
# Data\Image_100%\val\churros In there are  0  files and  100 images
# Data\Image_100%\val\clam_chowder In there are  0  files and  100 images
# Data\Image_100%\val\club_sandwich In there are  0  files and  100 images
# Data\Image_100%\val\crab_cakes In there are  0  files and  100 images
# Data\Image_100%\val\creme_brulee In there are  0  files and  100 images
# Data\Image_100%\val\croque_madame In there are  0  files and  100 images
# Data\Image_100%\val\cup_cakes In there are  0  files and  100 images
# Data\Image_100%\val\deviled_eggs In there are  0  files and  100 images
# Data\Image_100%\val\donuts In there are  0  files and  100 images
# Data\Image_100%\val\dumplings In there are  0  files and  100 images
# Data\Image_100%\val\edamame In there are  0  files and  100 images
# Data\Image_100%\val\eggs_benedict In there are  0  files and  100 images
# Data\Image_100%\val\escargots In there are  0  files and  100 images
# Data\Image_100%\val\falafel In there are  0  files and  100 images
# Data\Image_100%\val\filet_mignon In there are  0  files and  100 images
# Data\Image_100%\val\fish_and_chips In there are  0  files and  100 images
# Data\Image_100%\val\foie_gras In there are  0  files and  100 images
# Data\Image_100%\val\french_fries In there are  0  files and  100 images
# Data\Image_100%\val\french_onion_soup In there are  0  files and  100 images
# Data\Image_100%\val\french_toast In there are  0  files and  100 images
# Data\Image_100%\val\fried_calamari In there are  0  files and  100 images
# Data\Image_100%\val\fried_rice In there are  0  files and  100 images
# Data\Image_100%\val\frozen_yogurt In there are  0  files and  100 images
# Data\Image_100%\val\garlic_bread In there are  0  files and  100 images
# Data\Image_100%\val\gnocchi In there are  0  files and  100 images
# Data\Image_100%\val\greek_salad In there are  0  files and  100 images
# Data\Image_100%\val\grilled_cheese_sandwich In there are  0  files and  100 images
# Data\Image_100%\val\grilled_salmon In there are  0  files and  100 images
# Data\Image_100%\val\guacamole In there are  0  files and  100 images
# Data\Image_100%\val\gyoza In there are  0  files and  100 images
# Data\Image_100%\val\hamburger In there are  0  files and  100 images
# Data\Image_100%\val\hot_and_sour_soup In there are  0  files and  100 images
# Data\Image_100%\val\hot_dog In there are  0  files and  100 images
# Data\Image_100%\val\huevos_rancheros In there are  0  files and  100 images
# Data\Image_100%\val\hummus In there are  0  files and  100 images
# Data\Image_100%\val\ice_cream In there are  0  files and  100 images
# Data\Image_100%\val\lasagna In there are  0  files and  100 images
# Data\Image_100%\val\lobster_bisque In there are  0  files and  100 images
# Data\Image_100%\val\lobster_roll_sandwich In there are  0  files and  100 images
# Data\Image_100%\val\macaroni_and_cheese In there are  0  files and  100 images
# Data\Image_100%\val\macarons In there are  0  files and  100 images
# Data\Image_100%\val\miso_soup In there are  0  files and  100 images
# Data\Image_100%\val\mussels In there are  0  files and  100 images
# Data\Image_100%\val\nachos In there are  0  files and  100 images
# Data\Image_100%\val\omelette In there are  0  files and  100 images
# Data\Image_100%\val\onion_rings In there are  0  files and  100 images
# Data\Image_100%\val\oysters In there are  0  files and  100 images
# Data\Image_100%\val\pad_thai In there are  0  files and  100 images
# Data\Image_100%\val\paella In there are  0  files and  100 images
# Data\Image_100%\val\pancakes In there are  0  files and  100 images
# Data\Image_100%\val\panna_cotta In there are  0  files and  100 images
# Data\Image_100%\val\peking_duck In there are  0  files and  100 images
# Data\Image_100%\val\pho In there are  0  files and  100 images
# Data\Image_100%\val\pizza In there are  0  files and  100 images
# Data\Image_100%\val\pork_chop In there are  0  files and  100 images
# Data\Image_100%\val\poutine In there are  0  files and  100 images
# Data\Image_100%\val\prime_rib In there are  0  files and  100 images
# Data\Image_100%\val\pulled_pork_sandwich In there are  0  files and  100 images
# Data\Image_100%\val\ramen In there are  0  files and  100 images
# Data\Image_100%\val\ravioli In there are  0  files and  100 images
# Data\Image_100%\val\red_velvet_cake In there are  0  files and  100 images
# Data\Image_100%\val\risotto In there are  0  files and  100 images
# Data\Image_100%\val\samosa In there are  0  files and  100 images
# Data\Image_100%\val\sashimi In there are  0  files and  100 images
# Data\Image_100%\val\scallops In there are  0  files and  100 images
# Data\Image_100%\val\seaweed_salad In there are  0  files and  100 images
# Data\Image_100%\val\shrimp_and_grits In there are  0  files and  100 images
# Data\Image_100%\val\spaghetti_bolognese In there are  0  files and  100 images
# Data\Image_100%\val\spaghetti_carbonara In there are  0  files and  100 images
# Data\Image_100%\val\spring_rolls In there are  0  files and  100 images
# Data\Image_100%\val\steak In there are  0  files and  100 images
# Data\Image_100%\val\strawberry_shortcake In there are  0  files and  100 images
# Data\Image_100%\val\sushi In there are  0  files and  100 images
# Data\Image_100%\val\tacos In there are  0  files and  100 images
# Data\Image_100%\val\takoyaki In there are  0  files and  100 images
# Data\Image_100%\val\tiramisu In there are  0  files and  100 images
# Data\Image_100%\val\tuna_tartare In there are  0  files and  100 images
# Data\Image_100%\val\waffles In there are  0  files and  100 images

# %%
Data.put_labels("Labels")
